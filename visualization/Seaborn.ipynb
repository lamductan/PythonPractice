# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(sum(map(ord, "aesthetics")))

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sinplot()

# %%
sns.set()
sinplot()

# %%
sns.set_style('whitegrid')
data = np.random.normal(size=(20,6))
sns.boxplot(data=data)

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data);

# %%
f, ax = plt.subplots()
sns.violinplot(data=data)
sns.despine(offset=10, trim=True);

# %%
f, ax = plt.subplots()
sns.violinplot(data=data)
sns.despine(offset=10, trim=False)

# %%
f, ax = plt.subplots()
sns.violinplot(data=data)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %%
x = np.random.normal(size=100)
sns.distplot(x)
# Out:
# /home/tan/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
x = np.random.normal(size=100)
sns.distplot(x)
# Out:
# /home/tan/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
pal = sns.hls_palette(8, l=.3, s=.8)
sns.set_palette(palette=pal)
sns.distplot(x)
# Out:
# /home/tan/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set_palette(palette=sns.color_palette("BuGn_r"))
sns.distplot(x)
# Out:
# /home/tan/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

# %%
sns.jointplot(x="x", y="y", data=df)
# Out:
# /home/tan/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style('white'):
    sns.jointplot(x, y, kind='hex', color='k')
# Out:
# /home/tan/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style('white'):
    sns.jointplot(x, y, kind='hex', color='brown')
# Out:
# /home/tan/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x, y, kind='re', color='brown')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-ad83e0d8b5d7> in <module>()
# ----> 1 sns.jointplot(x, y, kind='re', color='brown')
#
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2301     else:
#    2302         msg = "kind must be either 'scatter', 'reg', 'resid', 'kde', or 'hex'"
# -> 2303         raise ValueError(msg)
#    2304
#    2305     if stat_func is not None:
#
# ValueError: kind must be either 'scatter', 'reg', 'resid', 'kde', or 'hex'
